# %%
# !pip install linearmodels
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting linearmodels
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1a/69/4459db6420946587c24898cb0901600afdcd0f8d2d4026d5f38fc76ef33a/linearmodels-5.4-cp311-cp311-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#      - -------------------------------------- 0.1/1.7 MB 991.0 kB/s eta 0:00:02
#      --- ------------------------------------ 0.1/1.7 MB 1.2 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.2/1.7 MB 1.3 MB/s eta 0:00:02
#      ------- -------------------------------- 0.3/1.7 MB 1.5 MB/s eta 0:00:01
#      -------- ------------------------------- 0.3/1.7 MB 1.4 MB/s eta 0:00:01
#      --------- ------------------------------ 0.4/1.7 MB 1.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.5/1.7 MB 1.4 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.5/1.7 MB 1.4 MB/s eta 0:00:01
#      -------------- ------------------------- 0.6/1.7 MB 1.5 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.7/1.7 MB 1.5 MB/s eta 0:00:01
#      ----------------- ---------------------- 0.7/1.7 MB 1.5 MB/s eta 0:00:01
#      -------------------- ------------------- 0.8/1.7 MB 1.5 MB/s eta 0:00:01
#      --------------------- ------------------ 0.9/1.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.0/1.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------ --------------- 1.0/1.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------- -------------- 1.1/1.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------- -------------- 1.1/1.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------- ---------- 1.2/1.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------ --------- 1.3/1.7 MB 1.5 MB/s eta 0:00:01
#      -------------------------------- ------- 1.3/1.7 MB 1.5 MB/s eta 0:00:01
#      -------------------------------- ------- 1.4/1.7 MB 1.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 1.5/1.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 1.5/1.7 MB 1.5 MB/s eta 0:00:01
#      ------------------------------------- -- 1.6/1.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  1.6/1.7 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------- 1.7/1.7 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.22.0 in c:\programdata\anaconda3\lib\site-packages (from linearmodels) (1.24.3)
# Requirement already satisfied: pandas>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from linearmodels) (2.0.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from linearmodels) (1.11.1)
# Requirement already satisfied: statsmodels>=0.12.0 in c:\programdata\anaconda3\lib\site-packages (from linearmodels) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.4 in c:\programdata\anaconda3\lib\site-packages (from linearmodels) (1.0.0)
# Collecting Cython>=0.29.37 (from linearmodels)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/20/50/638cbeb5b202b39d0605f6170fe25ed75287152827b0282d64135995b32b/Cython-3.0.9-cp311-cp311-win_amd64.whl (2.8 MB)
#      ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.8 MB 1.9 MB/s eta 0:00:02
#       --------------------------------------- 0.1/2.8 MB 1.1 MB/s eta 0:00:03
#      -- ------------------------------------- 0.2/2.8 MB 1.8 MB/s eta 0:00:02
#      --- ------------------------------------ 0.2/2.8 MB 1.4 MB/s eta 0:00:02
#      --- ------------------------------------ 0.3/2.8 MB 1.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.4/2.8 MB 1.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 0.4/2.8 MB 1.4 MB/s eta 0:00:02
#      ------ --------------------------------- 0.5/2.8 MB 1.4 MB/s eta 0:00:02
#      ------- -------------------------------- 0.5/2.8 MB 1.4 MB/s eta 0:00:02
#      -------- ------------------------------- 0.6/2.8 MB 1.4 MB/s eta 0:00:02
#      --------- ------------------------------ 0.6/2.8 MB 1.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.7/2.8 MB 1.5 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.7/2.8 MB 1.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 0.7/2.8 MB 1.4 MB/s eta 0:00:02
#      ----------- ---------------------------- 0.8/2.8 MB 1.3 MB/s eta 0:00:02
#      ------------- -------------------------- 0.9/2.8 MB 1.4 MB/s eta 0:00:02
#      ------------- -------------------------- 1.0/2.8 MB 1.4 MB/s eta 0:00:02
#      -------------- ------------------------- 1.0/2.8 MB 1.4 MB/s eta 0:00:02
#      --------------- ------------------------ 1.1/2.8 MB 1.4 MB/s eta 0:00:02
#      ---------------- ----------------------- 1.2/2.8 MB 1.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.2/2.8 MB 1.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 1.2/2.8 MB 1.3 MB/s eta 0:00:02
#      ------------------ --------------------- 1.3/2.8 MB 1.3 MB/s eta 0:00:02
#      ------------------ --------------------- 1.3/2.8 MB 1.3 MB/s eta 0:00:02
#      ------------------- -------------------- 1.4/2.8 MB 1.3 MB/s eta 0:00:02
#      -------------------- ------------------- 1.4/2.8 MB 1.3 MB/s eta 0:00:02
#      -------------------- ------------------- 1.5/2.8 MB 1.3 MB/s eta 0:00:02
#      --------------------- ------------------ 1.5/2.8 MB 1.3 MB/s eta 0:00:02
#      ---------------------- ----------------- 1.6/2.8 MB 1.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.6/2.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------ --------------- 1.7/2.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------ --------------- 1.7/2.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------- -------------- 1.8/2.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------- -------------- 1.8/2.8 MB 1.3 MB/s eta 0:00:01
#      -------------------------- ------------- 1.9/2.8 MB 1.2 MB/s eta 0:00:01
#      --------------------------- ------------ 1.9/2.8 MB 1.2 MB/s eta 0:00:01
#      --------------------------- ------------ 1.9/2.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.0/2.8 MB 1.2 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.0/2.8 MB 1.2 MB/s eta 0:00:01
#      ----------------------------- ---------- 2.0/2.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------ --------- 2.1/2.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------- -------- 2.2/2.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------- -------- 2.2/2.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------- ------- 2.3/2.8 MB 1.2 MB/s eta 0:00:01
#      --------------------------------- ------ 2.3/2.8 MB 1.2 MB/s eta 0:00:01
#      --------------------------------- ------ 2.3/2.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.4/2.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 2.4/2.8 MB 1.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.5/2.8 MB 1.2 MB/s eta 0:00:01
#      ----------------------------------- ---- 2.5/2.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------- -- 2.6/2.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 2.7/2.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 2.7/2.8 MB 1.2 MB/s eta 0:00:01
#      -------------------------------------- - 2.7/2.8 MB 1.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.8/2.8 MB 1.2 MB/s eta 0:00:00
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2f/51/cb006fbc08c32f161035fb19ca718250eb5f6d0692ea6dcc1e62c3e556a2/pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Collecting formulaic>=0.6.5 (from linearmodels)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2c/09/7a9f95d35106d882f79ddabc2d33d8f2a262863f1f5d6fd00f46c5fc90aa/formulaic-1.0.1-py3-none-any.whl (94 kB)
#      ---------------------------------------- 0.0/94.2 kB ? eta -:--:--
#      -------------------------- ------------- 61.4/94.2 kB 1.1 MB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      ---------------------------- --------- 71.7/94.2 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 94.2/94.2 kB 103.4 kB/s eta 0:00:00
# Collecting setuptools-scm[toml]<9.0.0,>=8.0.0 (from linearmodels)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/0e/a3/b9a8b0adfe672bf0df5901707aa929d30a97ee390ba651910186776746d2/setuptools_scm-8.0.4-py3-none-any.whl (42 kB)
#      ---------------------------------------- 0.0/42.1 kB ? eta -:--:--
#      ----------------------------- ---------- 30.7/42.1 kB 1.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 30.7/42.1 kB 1.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 30.7/42.1 kB 1.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 30.7/42.1 kB 1.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 30.7/42.1 kB 1.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 30.7/42.1 kB 1.4 MB/s eta 0:00:01
#      -------------------------------------- 42.1/42.1 kB 107.8 kB/s eta 0:00:00
# Collecting interface-meta>=1.2.0 (from formulaic>=0.6.5->linearmodels)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/02/3f/a6ec28c88e2d8e54d32598a1e0b5208a4baa72a8e7f6e241beab5731eb9d/interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from formulaic>=0.6.5->linearmodels) (4.7.1)
# Requirement already satisfied: wrapt>=1.0 in c:\programdata\anaconda3\lib\site-packages (from formulaic>=0.6.5->linearmodels) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->linearmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->linearmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.3.0->linearmodels) (2023.3)
# Requirement already satisfied: packaging>=20 in c:\programdata\anaconda3\lib\site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (23.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (68.0.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels>=0.12.0->linearmodels) (0.5.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.12.0->linearmodels) (1.16.0)
# Installing collected packages: setuptools-scm, interface-meta, Cython, pyhdfe, formulaic, linearmodels
# Successfully installed Cython-3.0.9 formulaic-1.0.1 interface-meta-1.3.0 linearmodels-5.4 pyhdfe-0.2.0 setuptools-scm-8.0.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
# Open your CPS80 from Pearson's website
df1 = pd.read_stata('https://wps.pearsoned.com/wps/media/objects/11422/11696965/empirical/empex_tb/cps08.dta')
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Open your CPS80 from Pearson's website
# ----> 2 df1 = pd.read_stata('https://wps.pearsoned.com/wps/media/objects/11422/11696965/empirical/empex_tb/cps08.dta')
#       3 df1
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\stata.py:2090, in read_stata(filepath_or_buffer, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals, chunksize, iterator, compression, storage_options)
#    2087     return reader
#    2089 with reader:
# -> 2090     return reader.read()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\stata.py:1702, in StataReader.read(self, nrows, convert_dates, convert_categoricals, index_col, convert_missing, preserve_dtypes, columns, order_categoricals)
#    1690 @Appender(_read_method_doc)
#    1691 def read(
#    1692     self,
#    (...)
#    1700     order_categoricals: bool | None = None,
#    1701 ) -> DataFrame:
# -> 1702     self._ensure_open()
#    1703     # Handle empty file or chunk.  If reading incrementally raise
#    1704     # StopIteration.  If reading the whole thing return an empty
#    1705     # data frame.
#    1706     if (self._nobs == 0) and (nrows is None):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\stata.py:1176, in StataReader._ensure_open(self)
#    1172 """
#    1173 Ensure the file has been opened and its header data read.
#    1174 """
#    1175 if not hasattr(self, "_path_or_buf"):
# -> 1176     self._open_file()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\stata.py:1206, in StataReader._open_file(self)
#    1203         self._path_or_buf = BytesIO(handles.handle.read())
#    1204     self._close_file = self._path_or_buf.close
# -> 1206 self._read_header()
#    1207 self._setup_dtype()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\stata.py:1288, in StataReader._read_header(self)
#    1286     self._read_new_header()
#    1287 else:
# -> 1288     self._read_old_header(first_char)
#    1290 self._has_string_data = len([x for x in self._typlist if type(x) is int]) > 0
#    1292 # calculate size of a data record
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\stata.py:1467, in StataReader._read_old_header(self, first_char)
#    1465 self._format_version = int(first_char[0])
#    1466 if self._format_version not in [104, 105, 108, 111, 113, 114, 115]:
# -> 1467     raise ValueError(_version_error.format(version=self._format_version))
#    1468 self._set_encoding()
#    1469 self._byteorder = ">" if self._read_int8() == 0x1 else "<"
#
# ValueError: Version of given Stata file is 13. pandas supports importing versions 105, 108, 111 (Stata 7SE), 113 (Stata 8/9), 114 (Stata 10/11), 115 (Stata 12), 117 (Stata 13), 118 (Stata 14/15/16),and 119 (Stata 15/16, over 32,767 variables).
